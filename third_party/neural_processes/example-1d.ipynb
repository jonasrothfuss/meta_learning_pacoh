# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
# %matplotlib inline

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Neural Process for 1D functions
#
# This notebook shows how to train and sample from a Neural Process for a simple class of 1D functions. The functions are defined by f(x) = a * sin(x - b) where a and b and randomly sampled.

# %% [markdown]
# ### Visualize Data

# %%
from datasets import SineData
from math import pi

# Create dataset
dataset = SineData(amplitude_range=(-1., 1.),
                   shift_range=(-.5, .5),
                   num_samples=2000)

# Visualize data samples
for i in range(64):
    x, y = dataset[i] 
    plt.plot(x.numpy(), y.numpy(), c='b', alpha=0.5)
    plt.xlim(-pi, pi)

# %% [markdown]
# ### Build Neural Process

# %%
from neural_process import NeuralProcess

x_dim = 1
y_dim = 1
r_dim = 50  # Dimension of representation of context points
z_dim = 50  # Dimension of sampled latent variable
h_dim = 50  # Dimension of hidden layers in encoder and decoder

neuralprocess = NeuralProcess(x_dim, y_dim, r_dim, z_dim, h_dim)

# %% [markdown]
# ### Visualize samples from prior
#
# We can visualize the prior (i.e. the output of the neural process without any context points) before training.

# %%
# Create a set of 100 target points, with shape 
# (batch_size, num_points, x_dim), which in this case is
# (1, 100, 1)
x_target = torch.Tensor(np.linspace(-pi, pi, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

for i in range(64):
    z_sample = torch.randn((1, z_dim))  # Shape (batch_size, z_dim)
    # Map x_target and z to p_y_target (which is parameterized by a 
    # normal with mean mu and std dev sigma)
    mu, _ = neuralprocess.xz_to_y(x_target, z_sample)
    # Plot predicted mean at each target point (note we could also
    # sample from distribution but plot mean for simplicity)
    plt.plot(x_target.numpy()[0], mu.detach().numpy()[0], 
             c='b', alpha=0.5)
    plt.xlim(-pi, pi)

# %% [markdown]
# ### Train Neural Process

# %%
from torch.utils.data import DataLoader
from training import NeuralProcessTrainer

batch_size = 2
num_context = 4
num_target = 4

data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
optimizer = torch.optim.Adam(neuralprocess.parameters(), lr=3e-4)
np_trainer = NeuralProcessTrainer(device, neuralprocess, optimizer,
                                  num_context_range=(num_context, num_context),
                                  num_extra_target_range=(num_target, num_target), 
                                  print_freq=200)

neuralprocess.training = True
np_trainer.train(data_loader, 30)
# Out:
# iteration 200, loss 3.221
# iteration 400, loss 6.031
# iteration 600, loss 2.201
# iteration 800, loss 2.910
# iteration 1000, loss -0.179
# Epoch: 0, Avg_loss: 3.9860324964430185
# iteration 1200, loss 2.927
# iteration 1400, loss 4.741
# iteration 1600, loss -4.083
# iteration 1800, loss 6.971
# iteration 2000, loss -4.050
# Epoch: 1, Avg_loss: 2.107994142986834
# iteration 2200, loss 1.176
# iteration 2400, loss -0.431
# iteration 2600, loss 4.894
# iteration 2800, loss -5.442
# iteration 3000, loss -2.051
# Epoch: 2, Avg_loss: 2.005094542354345
# iteration 3200, loss 4.438
# iteration 3400, loss 3.645
# iteration 3600, loss 5.437
# iteration 3800, loss 5.998
# iteration 4000, loss -1.725
# Epoch: 3, Avg_loss: 1.9593739635311067
# iteration 4200, loss 5.828
# iteration 4400, loss 6.832
# iteration 4600, loss -0.167
# iteration 4800, loss 4.537
# iteration 5000, loss -7.768
# Epoch: 4, Avg_loss: 1.876071878515184
# iteration 5200, loss -1.459
# iteration 5400, loss -5.094
# iteration 5600, loss -0.542
# iteration 5800, loss 1.361
# iteration 6000, loss 0.038
# Epoch: 5, Avg_loss: 1.8585714255874046
# iteration 6200, loss 3.243
# iteration 6400, loss 1.950
# iteration 6600, loss 2.720
# iteration 6800, loss 6.657
# iteration 7000, loss -4.942
# Epoch: 6, Avg_loss: 1.8521532730087638
# iteration 7200, loss 6.499
# iteration 7400, loss -2.920
# iteration 7600, loss 5.535
# iteration 7800, loss 3.287
# iteration 8000, loss 0.891
# Epoch: 7, Avg_loss: 1.7803237789310515
# iteration 8200, loss 1.336
# iteration 8400, loss 6.157
# iteration 8600, loss -0.767
# iteration 8800, loss -9.682
# iteration 9000, loss -3.365
# Epoch: 8, Avg_loss: 0.3560565260909498
# iteration 9200, loss 0.670
# iteration 9400, loss -3.095
# iteration 9600, loss -6.480
# iteration 9800, loss -4.571
# iteration 10000, loss -6.284
# Epoch: 9, Avg_loss: -3.250610277287662
# iteration 10200, loss -1.371
# iteration 10400, loss -2.608
# iteration 10600, loss -6.214
# iteration 10800, loss -8.616
# iteration 11000, loss -0.851
# Epoch: 10, Avg_loss: -4.360050644099712
# iteration 11200, loss -3.651
# iteration 11400, loss 3.280
# iteration 11600, loss -5.703
# iteration 11800, loss -7.320
# iteration 12000, loss -5.192
# Epoch: 11, Avg_loss: -4.882817383602261
# iteration 12200, loss -1.004
# iteration 12400, loss -7.509
# iteration 12600, loss -0.270
# iteration 12800, loss -6.129
# iteration 13000, loss -7.186
# Epoch: 12, Avg_loss: -5.140850869655609
# iteration 13200, loss 0.158
# iteration 13400, loss -2.924
# iteration 13600, loss -3.686
# iteration 13800, loss -3.927
# iteration 14000, loss -5.292
# Epoch: 13, Avg_loss: -5.1731867415755985
# iteration 14200, loss -1.544
# iteration 14400, loss -5.136
# iteration 14600, loss -7.223
# iteration 14800, loss -7.506
# iteration 15000, loss -6.218
# Epoch: 14, Avg_loss: -5.217400704145431
# iteration 15200, loss -6.553
# iteration 15400, loss -4.494
# iteration 15600, loss -4.305
# iteration 15800, loss -7.356
# iteration 16000, loss -9.694
# Epoch: 15, Avg_loss: -5.433700706019998
# iteration 16200, loss -2.671
# iteration 16400, loss -9.086
# iteration 16600, loss -5.794
# iteration 16800, loss -9.927
# iteration 17000, loss -7.728
# Epoch: 16, Avg_loss: -5.456625334456563
# iteration 17200, loss -6.856
# iteration 17400, loss -3.626
# iteration 17600, loss -2.101
# iteration 17800, loss -7.581
# iteration 18000, loss -8.715
# Epoch: 17, Avg_loss: -5.678787314414978
# iteration 18200, loss -6.243
# iteration 18400, loss -2.553
# iteration 18600, loss -7.526
# iteration 18800, loss -8.570
# iteration 19000, loss -1.089
# Epoch: 18, Avg_loss: -5.720378509372472
# iteration 19200, loss -10.603
# iteration 19400, loss 1.325
# iteration 19600, loss -4.428
# iteration 19800, loss -9.164
# iteration 20000, loss -4.755
# Epoch: 19, Avg_loss: -5.70156607362628
# iteration 20200, loss -5.128
# iteration 20400, loss -3.871
# iteration 20600, loss -4.971
# iteration 20800, loss -9.511
# iteration 21000, loss -9.646
# Epoch: 20, Avg_loss: -5.891602180421352
# iteration 21200, loss -3.307
# iteration 21400, loss -8.374
# iteration 21600, loss -8.432
# iteration 21800, loss -1.088
# iteration 22000, loss -9.270
# Epoch: 21, Avg_loss: -6.096317261591554
# iteration 22200, loss -6.161
# iteration 22400, loss -9.604
# iteration 22600, loss -7.183
# iteration 22800, loss -8.369
# iteration 23000, loss -5.751
# Epoch: 22, Avg_loss: -6.215845120072365
# iteration 23200, loss -4.993
# iteration 23400, loss -8.020
# iteration 23600, loss -7.505
# iteration 23800, loss -3.766
# iteration 24000, loss -10.601
# Epoch: 23, Avg_loss: -6.601125217661261
# iteration 24200, loss -8.846
# iteration 24400, loss -8.881
# iteration 24600, loss -1.406
# iteration 24800, loss -4.799
# iteration 25000, loss -10.353
# Epoch: 24, Avg_loss: -6.469458791479468
# iteration 25200, loss -8.224
# iteration 25400, loss -8.457
# iteration 25600, loss -7.152
# iteration 25800, loss -8.432
# iteration 26000, loss -7.085
# Epoch: 25, Avg_loss: -6.777004486232996
# iteration 26200, loss -7.697
# iteration 26400, loss -7.171
# iteration 26600, loss -5.912
# iteration 26800, loss -8.629
# iteration 27000, loss -7.718
# Epoch: 26, Avg_loss: -6.702884948670864
# iteration 27200, loss -9.961
# iteration 27400, loss -7.952
# iteration 27600, loss -9.096
# iteration 27800, loss -8.979
# iteration 28000, loss -8.625
# Epoch: 27, Avg_loss: -6.703413968451321
# iteration 28200, loss -6.857
# iteration 28400, loss -8.123
# iteration 28600, loss -1.627
# iteration 28800, loss -10.349
# iteration 29000, loss -9.294
# Epoch: 28, Avg_loss: -6.870601891189813
# iteration 29200, loss -8.116
# iteration 29400, loss -6.358
# iteration 29600, loss -1.946
# iteration 29800, loss -2.329
# iteration 30000, loss -9.778
# Epoch: 29, Avg_loss: -6.952230921387672

# %% [markdown]
# ### Visualize samples from trained prior
#
# The prior should now encode some information about the shapes of the functions.

# %%
x_target = torch.Tensor(np.linspace(-pi, pi, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

for i in range(64):
    z_sample = torch.randn((1, z_dim))
    mu, _ = neuralprocess.xz_to_y(x_target, z_sample)
    plt.plot(x_target.numpy()[0], mu.detach().numpy()[0], 
             c='b', alpha=0.5)
    plt.xlim(-pi, pi)

# %% [markdown]
# ### Visualize samples from posterior

# %%
from utils import context_target_split

# Extract a batch from data_loader
for batch in data_loader:
    break

# Use batch to create random set of context points
x, y = batch
x_context, y_context, _, _ = context_target_split(x[0:1], y[0:1], 
                                                  num_context, 
                                                  num_target)

# Create a set of target points corresponding to entire [-pi, pi] range
x_target = torch.Tensor(np.linspace(-pi, pi, 100))
x_target = x_target.unsqueeze(1).unsqueeze(0)

neuralprocess.training = False

for i in range(64):
    # Neural process returns distribution over y_target
    p_y_pred = neuralprocess(x_context, y_context, x_target)
    # Extract mean of distribution
    mu = p_y_pred.loc.detach()
    plt.plot(x_target.numpy()[0], mu.numpy()[0], 
             alpha=0.05, c='b')

plt.scatter(x_context[0].numpy(), y_context[0].numpy(), c='k')
